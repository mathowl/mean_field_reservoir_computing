# %%
import numpy as np
import matplotlib.pyplot as plt
import random
import math
import shelve
import string
import numba as nb
import timeit
import matplotlib.cm as cm
from matplotlib.colors import Normalize
from matplotlib import colors
import shelve
import uuid

# %%
with shelve.open('data/data_sets.shelve', 'r') as shelf:
    data = shelf['lorenz'] 
    
data_scaled = data
data_sampled= data_scaled [:,::20]

ut0 = data_scaled[:,::20]
utmid = data_scaled[:,10:][:,::20]
ut1 = data_scaled[:,20:][:,::20]

# %%
def f(z, u, omega,K,F,pvec):
    M  = len(z)
    df = np.zeros(M,dtype = 'complex_')
    for j in range(M):
        zdum =0 
        for i in range(M):
            zdum+= np.conjugate(z[i])*z[j]**2 - z[i] 
        df[j]  =  (F/2)*(np.exp(1j*u[pvec[j]]) - np.exp(-1*1j*u[pvec[j]])*z[j]**2) + (1j*omega[j]-1)*z[j]  -\
        K*(zdum)/(2*M)
    return df

def frk4_step(z,u0,umid,u1,h,w,K,F,pvec):
    k1 = h * f( z, u0,w,K,F,pvec)
    k2 = h * f(z + 0.5 * k1, umid,w,K,F,pvec)
    k3 = h * f( z + 0.5 * k2, umid,w,K,F,pvec)
    k4 = h * f(z + k3, u1, w,K,F,pvec)
    znew = z + (1.0 / 6.0)*(k1 + 2 * k2 + 2 * k3 + k4)
    return znew

def whipeout(initlen, ut0,utmid,ut1, x0, h,w,p,pvec):
    uin, K,F= p[0],p[1], p[2]  
    for j in nb.prange(initlen):
        U0 = ut0[:,j]
        Umid = utmid[:,j]
        U1 = ut1[:,j]
        x  = frk4_step(x0,uin*U0,uin*Umid,uin*U1,h,w,K,F,pvec)
        x0 = x
    return x

def kura_run(M,runlen, ut0, utmid,ut1, x0, h,w,p,pvec):
    uin, K,F = p[0],p[1], p[2]
    X = np.empty((M,runlen),'complex_')
    for j in nb.prange(runlen):
        U0 = ut0[:,j]
        Umid = utmid[:,j]
        U1 = ut1[:,j]
        x  = frk4_step(x0,uin*U0,uin*Umid,uin*U1,h,w,K,F,pvec)
        x0 = x
        X[:,j] = x
    return X

@nb.njit() 
def numba_norm(a):
    n = a.shape[0]
    norm = 0
    for i in range(n):
        norm += a[i] * a[i]
    return np.sqrt(norm)

@nb.njit()
def NMSE(yeval,ydata):
    nmse = np.zeros(yeval.shape[0], dtype='float64')
    for i in nb.prange(yeval.shape[0]):
        for j in nb.prange(yeval.shape[1]):
            nmse[i] += (ydata[i,j]-yeval[i,j])**2
        nmse[i]=nmse[i]/numba_norm(ydata[i,:])**2
    return nmse


def test_closed(z0,p,Wout,w,h,M,N,s_steps,pvec):
    Ztest=np.zeros((M,s_steps), dtype='complex_')
    Upred=np.zeros((N,s_steps), dtype='float64')
    z=z0
    for i in nb.prange(s_steps):
        #print(z)
        z = frk4closed_step(z,p,Wout,w,h,M,pvec)
        Ztest[:,i] = z
        x=np.angle(z)
        Upred[:,i]= Wout @ np.hstack([1, np.sin(x), np.sin(x)**2])
    return Ztest, Upred

def frk4closed_step(y,p,Wout,w,h,M,pvec):
    k1 = h * fkura_closed( y,p,Wout,w,M,pvec)
    k2 = h * fkura_closed(y + 0.5 * k1, p,Wout,w,M,pvec)
    k3 = h * fkura_closed( y + 0.5 * k2, p,Wout,w,M,pvec)
    k4 = h * fkura_closed(y + k3, p,Wout,w,M,pvec)
    y = y + (1.0 / 6.0)*(k1 + 2 * k2 + 2 * k3 + k4)
    return y

def fkura_closed(z,p,Wout,omega,M,pvec):  
    uin, K,F = p[0],p[1],p[2]
    df = np.zeros(M,dtype='complex_')
    x = np.angle(z)
    
    Up0= Wout @ np.hstack([1, np.sin(x), np.sin(x)**2])
    for j in range(M):
        zdum =0 
        for i in range(M):
            zdum+= np.conjugate(z[i])*z[j]**2 - z[i] 
        df[j]  =  (F/2)*(np.exp(1j*Up0[pvec[j]]*uin) - np.exp(-1*1j*Up0[pvec[j]]*uin)*z[j]**2) \
        + (1j*omega[j]-1)*z[j] - K*(zdum)/(2*M)
    return df

# %%
def fVec(X,Wout,omega,p, pvec, M,N):
    uin, K,F = p[0],p[1],p[2]     

    x = np.zeros(M)
    y = np.zeros(M)

    for i in range(M):
        x[i] = X[i*2]
        y[i] = X[1+2*i]

    
    utest = np.zeros(M)

    Psiv = np.zeros(M)
    for j in range(M):
        Psiv[j] = np.arctan(y[j]/x[j])

    utest0 = np.zeros(N)
    utest0+= Wout[:,0]
    utest0+= Wout[:,1:M+1]@ np.sin(Psiv)
    utest0+= Wout[:,M+1:2*M+1]@ (np.sin(Psiv)**2)


    utest = np.zeros(M)
    for j in range(M):
        utest[j] = utest0[pvec[j]]*uin

    Y = np.zeros(2*M)
    for j in range(M):
        xdum = 0
        for i in range(M):
            xdum += x[i]*x[j]**2 + 2*y[i]*y[j]*x[j] - x[i]*y[j]**2 -x[i]
        Y[j*2] = -F*(2*x[j]*y[j]*np.sin(utest[j]) + (x[j]**2 - y[j]**2)*np.cos(utest[j]) - np.cos(utest[j]))/2 - x[j] - omega[j]*y[j]    - \
        (K/(2*M))*( xdum )
        ydum = 0
        for i in range(M):
            ydum += 2*x[i]*x[j]*y[j]-y[i]*x[j]**2+y[i]*y[j]**2-y[i] 
        Y[1+j*2] = F*(-2*x[j]*y[j]*np.cos(utest[j]) + (x[j]**2 - y[j]**2)*np.sin(utest[j]) + np.sin(utest[j]))/2  + omega[j]*x[j]-y[j] - \
        (K/(2*M))*( ydum )

    return Y


# def fVecrk4closed_step(X,Wout,omega,p, pvec, M,N):
#     k1 = h * fVec(X,Wout,omega,p, pvec, M,N)
#     k2 = h * fVec(X + 0.5 * k1,Wout,omega,p, pvec, M,N)
#     k3 = h * fVec( X + 0.5 * k2,Wout,omega,p, pvec, M,N)
#     k4 = h * fVec(X + k3,Wout,omega,p, pvec, M,N)
#     X = X + (1.0 / 6.0)*(k1 + 2 * k2 + 2 * k3 + k4)
#     return X

def X2u(X,Wout,M,N):
    x = np.zeros(M)
    y = np.zeros(M)
    for i in range(M):
        x[i] = X[i*2]
        y[i] = X[1+2*i]
    Psiv = np.zeros(M)
    for j in range(M):
        Psiv[j] = np.arctan(y[j]/x[j])

    utest = np.zeros(N)
    utest+= Wout[:,0]
    utest+= Wout[:,1:M+1]@ np.sin(Psiv)
    utest+= Wout[:,M+1:2*M+1]@ (np.sin(Psiv)**2)

    return utest

def jaci(X,Wout,omega,p,pvec,M,N):
    uin, K,F = p[0],p[1],p[2]
    x = np.zeros(M)
    y = np.zeros(M)
    
    for i in range(M):
        x[i] = X[i*2]
        y[i] = X[1+2*i]

    Psiv = np.zeros(M)
    for j in range(M):
        Psiv[j] = np.arctan(y[j]/x[j])
        
    utest0 = np.zeros(N)
    utest0+= Wout[:,0]
    utest0+= Wout[:,1:M+1]@ np.sin(Psiv)
    utest0+= Wout[:,M+1:2*M+1]@ (np.sin(Psiv)**2)

    utest = np.zeros(M)
    for j in range(M):
        utest[j] = utest0[pvec[j]]*uin
        
    
    Dutest = uin*Du_full(X,Wout,pvec,M,N)
    
    J = np.zeros((2*M,2*M))

    for j in range(M):
        for i in range(2*M):
            if 2*j == i:
                xjdum = 3*x[j]**2 + y[j]**2 -1
                for k in range(M):
                    if k != j:
                        xjdum +=2*x[k]*x[j] + 2*y[k]*y[j]

                J[2*j,i] = -F*(2*x[j]*y[j]*np.cos(utest[j])*Dutest[j,i] + 2*x[j]*np.cos(utest[j]) + 2.0*y[j]*np.sin(utest[j]) - \
                               (x[j]**2 - y[j]**2)*np.sin(utest[j])*Dutest[j,i] + np.sin(1.0*utest[j])*Dutest[j,i])/2  - 1  - (K/(2*M))*xjdum
                
                yjdum =  2 * x[j]*y[j]-1*y[j]*x[j]
                for k in range(M):
                    if k != j:
                        yjdum += x[k]*y[j]-y[k]*x[j]

                J[2*j+1,i] = F*(2.0*x[j]*y[j]*np.sin(utest[j])*Dutest[j,i] + 2.0*x[j]*np.sin(utest[j]) - 2.0*y[j]*np.cos(utest[j]) +  \
                                (x[j]**2 - y[j]**2)*np.cos(utest[j])*Dutest[j,i] + np.cos(utest[j])*Dutest[j,i])/2  + omega[j] - (K/(M))*(yjdum)
            elif (2*j +1)== i:
                #j=1 , i =1
                xjdum = y[j]*x[j]
                for k in range(M):
                    if k!= j:
                        xjdum += y[k]*x[j]- x[k]*y[j] 

                J[2*j,i] = -F*(2.0*x[j]*y[j]*np.cos(utest[j])*Dutest[j,i] + 2.0*x[j]*np.sin(utest[j]) - 2.0*y[j]*np.cos(utest[j]) - \
                               (x[j]**2 - 1.0*y[j]**2)*np.sin(utest[j])*Dutest[j,i] + 1.0*np.sin(1.0*utest[j])*Dutest[j,i])/2 - 1.0*omega[j] -(K/(M))*xjdum

                yjdum = x[j]**2 +3*y[j]**2 -1 
                for k in range(M):
                    if k != j:
                        yjdum += 2*x[k]*x[j]+2*y[k]*y[j]
    
                J[2*j+1,i] = F*(2.0*x[j]*y[j]*np.sin(utest[j])*Dutest[j,i] - 2.0*x[j]*np.cos(utest[j]) - 2.0*y[j]*np.sin(utest[j]) + \
                              1.0*(x[j]**2 - y[j]**2)*np.cos(utest[j])*Dutest[j,i] + 1.0*np.cos(1.0*utest[j])*Dutest[j,i])/2  - 1.0 - (K/(2*M))*yjdum

            elif ((i) % 2) ==0:
             
                J[2*j,i]= -F*(2.0*x[j]*y[j]*np.cos(utest[j]) - (x[j]**2 - 1.0*y[j]**2)*np.sin(utest[j]) + 1.0*np.sin(1.0*utest[j]))*Dutest[j,i]/2 + K*(-x[j]**2 + 1.0*y[j]**2 + 1)/(2*M)               
                J[2*j+1,i] =  F*(2.0*x[j]*y[j]*np.sin(utest[j]) + 1.0*(x[j]**2 - y[j]**2)*np.cos(utest[j]) + 1.0*np.cos(1.0*utest[j]))*Dutest[j,i]/2  -  K*x[j]*y[j]/M


            elif ((i) % 2) ==1:

                J[2*j,i]=  -F*(2.0*x[j]*y[j]*np.cos(utest[j]) - (x[j]**2 - 1.0*y[j]**2)*np.sin(utest[j]) + 1.0*np.sin(1.0*utest[j]))*Dutest[j,i]/2 - \
                K*x[j]*y[j]/M
                
                J[2*j+1,i] = F*(2.0*x[j]*y[j]*np.sin(utest[j]) + 1.0*(x[j]**2 - y[j]**2)*np.cos(utest[j]) + 1.0*np.cos(1.0*utest[j]))*Dutest[j,i]/2 + \
                K*(x[j]**2 - y[j]**2 + 1)/(2*M)
                
    return J

def sinpsi_x(x,y):
    return -y*np.abs(x)/(x**2 + y**2)**(3/2)
def sinpsi_y(x,y):
    return x*np.abs(x)/(x**2 + y**2)**(3/2)
def sin2psi_x(x,y):
    return -2*x*y**2/(x**2 + y**2)**2
def sin2psi_y(x,y):
    return 2*x**2*y/(x**4 + 2*x**2*y**2 + y**4)

def Du_full(X,Wtest, pvec, M,N):
    Dudum = np.zeros((N,2*M))
    Dutest = np.zeros((M,2*M))
    x = np.zeros(M)
    y = np.zeros(M)
    
    for i in range(M):
        x[i] = X[i*2]
        y[i] = X[1+2*i]

    
    W1 = Wtest[:,1:M+1]
    W2 = Wtest[:,M+1:2*M+1]


    for i in range(N):
        for j in range(M):
            Dudum[i,j*2]+= W1[i,j]*sinpsi_x(x[j],y[j])+ W2[i,j]*sin2psi_x(x[j],y[j])
            Dudum[i,j*2+1]+= W1[i,j]*sinpsi_y(x[j],y[j])+ W2[i,j]*sin2psi_y(x[j],y[j])
    
    for i in range(M):
        Dutest[i,:] = Dudum[pvec[i],:]
    return Dutest




def assemble(v, U, M,k):
    new_state = np.empty(M*2+2*M*k, dtype='float64')
    new_state[:M*2] = v 
    new_state[M*2:] = U.flatten()
    return new_state

def disassemble(state, M,k):
    new_v = state[:M*2] 
    new_U = state[M*2:].reshape(2*M, k)
    return new_v, new_U

def dSdt( f,fjac,Wout, omega, p, pvec, state, M,N,k):
    v, U = disassemble(state, M,k)
    dv = f(v, Wout, omega,p,pvec,M,N)
    dU = fjac(v, Wout, omega,p,pvec,M,N) @ U
    return assemble(dv, dU, M,k)

def varRK4(f, fjac,state, dt, Wout, omega,p,pvec,M,N,k):
    k1 = dt*dSdt( f, fjac, Wout, omega, p, pvec, state, M, N,k)
    k2 = dt*dSdt(f,fjac,Wout, omega, p, pvec, state + 0.5 * k1, M,N,k)
    k3 = dt*dSdt(f, fjac,Wout, omega, p, pvec, state + 0.5 * k2, M, N,k)
    k4 = dt*dSdt(f, fjac,Wout, omega, p, pvec,state +  k3, M, N,k)
    return state + (1/6) * (k1 + 2*k2 + 2*k3 + k4)

@nb.njit()
def gram_schmidt(U,k):
    N = np.shape(U)[0]
    W = U.copy().astype(np.float64)
    V = np.empty((N, k),dtype='float64')
    norms = np.empty(k,dtype='float64')
    for i in range(k):
        for j in range(i):
            W[:, i] = W[:, i] - numba_dot2(U[:, i], V[:, j]) * V[:, j]
        norms[i] = numba_norm(W[:, i])
        V[:, i] = W[:, i] / norms[i]
    return V, norms 

@nb.njit()
def numba_dot2(a, b):
    n = a.shape[0]
    dot = 0
    for i in range(n):
        dot += a[i] * b[i]
    return dot

@nb.njit() 
def numba_norm(a):
    n = a.shape[0]
    norm = 0
    for i in range(n):
        norm += a[i] * a[i]
    return np.sqrt(norm)

def solve_lya(x0, Wout,omega,p, pvec, M, N,m, dt,k=1):
    
    LEi_sort = []
    trJi_sort = []

    LE = np.zeros(k)  # Lyapunov exponents
    e = np.eye(2*M, k)  # make a matrix of variations (N x k)

    U_pred = np.zeros((3,m-1))
    traceJ = np.zeros(m)
    X=np.zeros((M*2,m))
    X[:,0] = x0
    
    LEi_sort = np.zeros((k,m-1))
    trJi_sort = np.zeros( (m-1) )
    k0=0 # indexing for first lya_dummy to compute mean and std
    trJ = 0  # integral of the trace of Jacobian matrix
    oldtraceJ =  np.trace(jaci(x0,Wout,omega,p,pvec,M,N)) # trace of Jacobian matrix in previous step   
    for i in range(0,m-1):
        state= assemble(X[:,i], e, M,k)        
        X[:,i+1], e = disassemble(varRK4(fVec, jaci, state, dt, Wout,omega,p,pvec,M,N,k),M,k)
        #print(e.shape)
        e, nrm = gram_schmidt(e,k)
        LE = LE + np.log(nrm)
        
        Up = X2u(X[:,i+1],Wout,M,N)
        U_pred[:,i]= Up  
        
        traceJ = np.trace(jaci(X[:,i+1],Wout,omega,p,pvec,M,N))
        trJ = trJ + 0.5 * dt * (oldtraceJ + traceJ)  # sum of LEs
        oldtraceJ = traceJ

        LEi_sort[:,i]= LE / (dt*(i+1))
        trJi_sort[i]= trJ / (dt*(i+1))
   
    return LEi_sort,trJi_sort , U_pred

# %%
for K0 in np.arange(3.5,5.5,0.125):
    initlen=5_000
    trainlen=20_000
    testlen=10_000
    M=4
    N=3
    pvec=[0,1,2,2]

    K0=np.round(K0,3)
    h=0.01
    F0 = 55
    uin = 0.01
    omega0 = np.round(np.array([ 0.4254, -0.0726, -0.0892,  0.0301]),2)
    p= np.array([uin,K0,F0])

    




    h=0.01
    reg=1e-11
    z0 = np.ones(M)
    while np.any(np.abs(z0)>1): 
        z0 = (np.random.rand(M)*1j + np.random.rand(M))


    znew = whipeout(initlen, ut0,utmid,ut1, z0, h,omega0,p,pvec)
    Ztrain = kura_run(M,trainlen, ut0[:,initlen:], utmid[:,initlen:],ut1[:,initlen:], znew, h,omega0,p,pvec)
    Xtrain = np.angle(Ztrain)
    X =  np.concatenate((np.expand_dims(np.ones(Xtrain.shape[1]),axis=0),np.sin(Xtrain),np.sin(Xtrain)**2),axis=0)

    Yt = data_scaled[:,::20][:,(initlen+1):(initlen+trainlen+1)].T
    Ytest = data_scaled[:,::20][:,(initlen+trainlen+1):(initlen+trainlen+1+testlen)]

    Wout = np.linalg.solve( np.dot(X,X.T) + reg*np.eye(2*len(z0)+1) , np.dot(X,Yt) ).T

    pred = (Wout @ X)
    nmse_train = NMSE(  pred, Yt.T).mean()
    print(nmse_train)
    z0 = Ztrain[:,-1]

    x0 = np.real(z0)
    y0 = np.imag(z0)
    X_Y = np.zeros(M*2)
    for i in range(M):
        X_Y[2*i] = x0[i]
        X_Y[2*i+1] = y0[i]
    LE,trJ , Upred =  solve_lya(X_Y, Wout,omega0,p,pvec, M, N, 10_000, h,k=M*2)
    LE_shelf = LE[:,5000:]
    ax = plt.figure().add_subplot(projection='3d')
    ax.plot(*Upred[:,:5_000], lw=0.5,alpha=0.5)

    ax.set_zlim(0, 43)
    ax.set_xlim(-20, 22)
    ax.set_ylim(-20, 22)
    ax.xaxis.set_ticks(np.arange(-20, 21, 10))
    ax.yaxis.set_ticks(np.arange(-20, 21, 10))
    ax.zaxis.set_ticks(np.arange(0, 41, 10))
    
    ax.xaxis.set_ticklabels([])
    ax.yaxis.set_ticklabels([])
    ax.zaxis.set_ticklabels([])
    plt.savefig(f'shelve/pictures_paper/4d/Kbifu_paper/{K0}_{np.round(LE[:3,-500:].mean(axis=1),3)}.jpg',dpi=300,bbox_inches = 'tight')
    plt.show()
    plt.close()
# Out:
# 0.0005996422319946457
# 0.0005711122895176562
# 0.000544769342639445
# 0.0005199506659447689
# 0.0004970020021292659
# 0.00047544760463647727
# 0.0004556243989391902
# 0.0004365479980457259
# 0.00041916884133323386
# 0.00040271487470091514
# 0.0003873407141236844
# 0.0003729055450028571
# 0.00035934670288016404
# 0.0003467219395365166
# 0.0003347013994526762
# 0.000323495677141375

# %%
Klist = []
LE_list =[]

for K0 in np.arange(3.5,55,0.125):
    initlen=5_000
    trainlen=20_000
    testlen=10_000
    M=4
    N=3
    pvec=[0,1,2,2]

    K0=np.round(K0,3)
    h=0.01
    F0 = 55
    uin = 0.01
    omega0 = np.round(np.array([ 0.4254, -0.0726, -0.0892,  0.0301]),2)
    p= np.array([uin,K0,F0])

    




    h=0.01
    reg=1e-11
    z0 = np.ones(M)
    while np.any(np.abs(z0)>1): 
        z0 = (np.random.rand(M)*1j + np.random.rand(M))


    znew = whipeout(initlen, ut0,utmid,ut1, z0, h,omega0,p,pvec)
    Ztrain = kura_run(M,trainlen, ut0[:,initlen:], utmid[:,initlen:],ut1[:,initlen:], znew, h,omega0,p,pvec)
    Xtrain = np.angle(Ztrain)
    X =  np.concatenate((np.expand_dims(np.ones(Xtrain.shape[1]),axis=0),np.sin(Xtrain),np.sin(Xtrain)**2),axis=0)

    Yt = data_scaled[:,::20][:,(initlen+1):(initlen+trainlen+1)].T
    Ytest = data_scaled[:,::20][:,(initlen+trainlen+1):(initlen+trainlen+1+testlen)]

    Wout = np.linalg.solve( np.dot(X,X.T) + reg*np.eye(2*len(z0)+1) , np.dot(X,Yt) ).T

    pred = (Wout @ X)
    nmse_train = NMSE(  pred, Yt.T).mean()
    print(nmse_train)
    z0 = Ztrain[:,-1]

    x0 = np.real(z0)
    y0 = np.imag(z0)
    X_Y = np.zeros(M*2)
    for i in range(M):
        X_Y[2*i] = x0[i]
        X_Y[2*i+1] = y0[i]
    LE,trJ , Upred =  solve_lya(X_Y, Wout,omega0,p,pvec, M, N, 10_000, h,k=M*2)
    LE_shelf = LE[:,5000:]
    
    Klist.append(K0)
    LE3 = np.round(LE[:3,-500:].mean(axis=1),3)
    LE_list.append(LE3)
# Out:
# 0.0018604753121029818
# C:\Users\Thomas\AppData\Local\Temp\ipykernel_41472\4256709949.py:32: RuntimeWarning: overflow encountered in double_scalars
#   xdum += x[i]*x[j]**2 + 2*y[i]*y[j]*x[j] - x[i]*y[j]**2 -x[i]
# C:\Users\Thomas\AppData\Local\Temp\ipykernel_41472\4256709949.py:32: RuntimeWarning: invalid value encountered in double_scalars
#   xdum += x[i]*x[j]**2 + 2*y[i]*y[j]*x[j] - x[i]*y[j]**2 -x[i]
# C:\Users\Thomas\AppData\Local\Temp\ipykernel_41472\4256709949.py:37: RuntimeWarning: overflow encountered in double_scalars
#   ydum += 2*x[i]*x[j]*y[j]-y[i]*x[j]**2+y[i]*y[j]**2-y[i]
# C:\Users\Thomas\AppData\Local\Temp\ipykernel_41472\4256709949.py:37: RuntimeWarning: invalid value encountered in double_scalars
#   ydum += 2*x[i]*x[j]*y[j]-y[i]*x[j]**2+y[i]*y[j]**2-y[i]
# C:\Users\Thomas\AppData\Local\Temp\ipykernel_41472\4256709949.py:153: RuntimeWarning: overflow encountered in double_scalars
#   return -2*x*y**2/(x**2 + y**2)**2
# C:\Users\Thomas\AppData\Local\Temp\ipykernel_41472\4256709949.py:155: RuntimeWarning: overflow encountered in double_scalars
#   return 2*x**2*y/(x**4 + 2*x**2*y**2 + y**4)
# C:\Users\Thomas\AppData\Local\Temp\ipykernel_41472\4256709949.py:149: RuntimeWarning: overflow encountered in double_scalars
#   return -y*np.abs(x)/(x**2 + y**2)**(3/2)
# C:\Users\Thomas\AppData\Local\Temp\ipykernel_41472\4256709949.py:153: RuntimeWarning: invalid value encountered in double_scalars
#   return -2*x*y**2/(x**2 + y**2)**2
# C:\Users\Thomas\AppData\Local\Temp\ipykernel_41472\4256709949.py:151: RuntimeWarning: overflow encountered in double_scalars
#   return x*np.abs(x)/(x**2 + y**2)**(3/2)
# C:\Users\Thomas\AppData\Local\Temp\ipykernel_41472\4256709949.py:155: RuntimeWarning: invalid value encountered in double_scalars
#   return 2*x**2*y/(x**4 + 2*x**2*y**2 + y**4)
# C:\Users\Thomas\AppData\Local\Temp\ipykernel_41472\4256709949.py:198: RuntimeWarning: overflow encountered in matmul
#   dU = fjac(v, Wout, omega,p,pvec,M,N) @ U
# C:\Users\Thomas\AppData\Local\Temp\ipykernel_41472\4256709949.py:198: RuntimeWarning: invalid value encountered in matmul
#   dU = fjac(v, Wout, omega,p,pvec,M,N) @ U
# 0.0017663207933673439
# C:\Users\Thomas\AppData\Local\Temp\ipykernel_41472\4256709949.py:149: RuntimeWarning: invalid value encountered in double_scalars
#   return -y*np.abs(x)/(x**2 + y**2)**(3/2)
# C:\Users\Thomas\AppData\Local\Temp\ipykernel_41472\4256709949.py:151: RuntimeWarning: invalid value encountered in double_scalars
#   return x*np.abs(x)/(x**2 + y**2)**(3/2)
# C:\Users\Thomas\AppData\Local\Temp\ipykernel_41472\4256709949.py:102: RuntimeWarning: overflow encountered in double_scalars
#   xjdum +=2*x[k]*x[j] + 2*y[k]*y[j]
# C:\Users\Thomas\AppData\Local\Temp\ipykernel_41472\4256709949.py:102: RuntimeWarning: invalid value encountered in double_scalars
#   xjdum +=2*x[k]*x[j] + 2*y[k]*y[j]
# C:\Users\Thomas\AppData\Local\Temp\ipykernel_41472\4256709949.py:110: RuntimeWarning: overflow encountered in double_scalars
#   yjdum += x[k]*y[j]-y[k]*x[j]
# C:\Users\Thomas\AppData\Local\Temp\ipykernel_41472\4256709949.py:119: RuntimeWarning: overflow encountered in double_scalars
#   xjdum += y[k]*x[j]- x[k]*y[j]
# C:\Users\Thomas\AppData\Local\Temp\ipykernel_41472\4256709949.py:127: RuntimeWarning: overflow encountered in double_scalars
#   yjdum += 2*x[k]*x[j]+2*y[k]*y[j]
# C:\Users\Thomas\AppData\Local\Temp\ipykernel_41472\4256709949.py:127: RuntimeWarning: invalid value encountered in double_scalars
#   yjdum += 2*x[k]*x[j]+2*y[k]*y[j]
# C:\Users\Thomas\AppData\Local\Temp\ipykernel_41472\4256709949.py:134: RuntimeWarning: overflow encountered in double_scalars
#   J[2*j,i]= -F*(2.0*x[j]*y[j]*np.cos(utest[j]) - (x[j]**2 - 1.0*y[j]**2)*np.sin(utest[j]) + 1.0*np.sin(1.0*utest[j]))*Dutest[j,i]/2 + K*(-x[j]**2 + 1.0*y[j]**2 + 1)/(2*M)
# C:\Users\Thomas\AppData\Local\Temp\ipykernel_41472\4256709949.py:134: RuntimeWarning: invalid value encountered in double_scalars
#   J[2*j,i]= -F*(2.0*x[j]*y[j]*np.cos(utest[j]) - (x[j]**2 - 1.0*y[j]**2)*np.sin(utest[j]) + 1.0*np.sin(1.0*utest[j]))*Dutest[j,i]/2 + K*(-x[j]**2 + 1.0*y[j]**2 + 1)/(2*M)
# C:\Users\Thomas\AppData\Local\Temp\ipykernel_41472\4256709949.py:135: RuntimeWarning: overflow encountered in double_scalars
#   J[2*j+1,i] =  F*(2.0*x[j]*y[j]*np.sin(utest[j]) + 1.0*(x[j]**2 - y[j]**2)*np.cos(utest[j]) + 1.0*np.cos(1.0*utest[j]))*Dutest[j,i]/2  -  K*x[j]*y[j]/M
# C:\Users\Thomas\AppData\Local\Temp\ipykernel_41472\4256709949.py:135: RuntimeWarning: invalid value encountered in double_scalars
#   J[2*j+1,i] =  F*(2.0*x[j]*y[j]*np.sin(utest[j]) + 1.0*(x[j]**2 - y[j]**2)*np.cos(utest[j]) + 1.0*np.cos(1.0*utest[j]))*Dutest[j,i]/2  -  K*x[j]*y[j]/M
# C:\Users\Thomas\AppData\Local\Temp\ipykernel_41472\4256709949.py:140: RuntimeWarning: overflow encountered in double_scalars
#   J[2*j,i]=  -F*(2.0*x[j]*y[j]*np.cos(utest[j]) - (x[j]**2 - 1.0*y[j]**2)*np.sin(utest[j]) + 1.0*np.sin(1.0*utest[j]))*Dutest[j,i]/2 - \
# C:\Users\Thomas\AppData\Local\Temp\ipykernel_41472\4256709949.py:140: RuntimeWarning: invalid value encountered in double_scalars
#   J[2*j,i]=  -F*(2.0*x[j]*y[j]*np.cos(utest[j]) - (x[j]**2 - 1.0*y[j]**2)*np.sin(utest[j]) + 1.0*np.sin(1.0*utest[j]))*Dutest[j,i]/2 - \
# C:\Users\Thomas\AppData\Local\Temp\ipykernel_41472\4256709949.py:141: RuntimeWarning: overflow encountered in double_scalars
#   K*x[j]*y[j]/M
# C:\Users\Thomas\AppData\Local\Temp\ipykernel_41472\4256709949.py:143: RuntimeWarning: overflow encountered in double_scalars
#   J[2*j+1,i] = F*(2.0*x[j]*y[j]*np.sin(utest[j]) + 1.0*(x[j]**2 - y[j]**2)*np.cos(utest[j]) + 1.0*np.cos(1.0*utest[j]))*Dutest[j,i]/2 + \
# C:\Users\Thomas\AppData\Local\Temp\ipykernel_41472\4256709949.py:143: RuntimeWarning: invalid value encountered in double_scalars
#   J[2*j+1,i] = F*(2.0*x[j]*y[j]*np.sin(utest[j]) + 1.0*(x[j]**2 - y[j]**2)*np.cos(utest[j]) + 1.0*np.cos(1.0*utest[j]))*Dutest[j,i]/2 + \
# C:\Users\Thomas\AppData\Local\Temp\ipykernel_41472\4256709949.py:144: RuntimeWarning: overflow encountered in double_scalars
#   K*(x[j]**2 - y[j]**2 + 1)/(2*M)
# C:\Users\Thomas\AppData\Local\Temp\ipykernel_41472\4256709949.py:144: RuntimeWarning: invalid value encountered in double_scalars
#   K*(x[j]**2 - y[j]**2 + 1)/(2*M)
# C:\Users\Thomas\AppData\Local\Temp\ipykernel_41472\4256709949.py:99: RuntimeWarning: overflow encountered in double_scalars
#   xjdum = 3*x[j]**2 + y[j]**2 -1
# C:\Users\Thomas\AppData\Local\Temp\ipykernel_41472\4256709949.py:104: RuntimeWarning: overflow encountered in double_scalars
#   J[2*j,i] = -F*(2*x[j]*y[j]*np.cos(utest[j])*Dutest[j,i] + 2*x[j]*np.cos(utest[j]) + 2.0*y[j]*np.sin(utest[j]) - \
# C:\Users\Thomas\AppData\Local\Temp\ipykernel_41472\4256709949.py:105: RuntimeWarning: overflow encountered in double_scalars
#   (x[j]**2 - y[j]**2)*np.sin(utest[j])*Dutest[j,i] + np.sin(1.0*utest[j])*Dutest[j,i])/2  - 1  - (K/(2*M))*xjdum
# C:\Users\Thomas\AppData\Local\Temp\ipykernel_41472\4256709949.py:105: RuntimeWarning: invalid value encountered in double_scalars
#   (x[j]**2 - y[j]**2)*np.sin(utest[j])*Dutest[j,i] + np.sin(1.0*utest[j])*Dutest[j,i])/2  - 1  - (K/(2*M))*xjdum
# C:\Users\Thomas\AppData\Local\Temp\ipykernel_41472\4256709949.py:107: RuntimeWarning: overflow encountered in double_scalars
#   yjdum =  2 * x[j]*y[j]-1*y[j]*x[j]
# C:\Users\Thomas\AppData\Local\Temp\ipykernel_41472\4256709949.py:107: RuntimeWarning: invalid value encountered in double_scalars
#   yjdum =  2 * x[j]*y[j]-1*y[j]*x[j]
# C:\Users\Thomas\AppData\Local\Temp\ipykernel_41472\4256709949.py:112: RuntimeWarning: overflow encountered in double_scalars
#   J[2*j+1,i] = F*(2.0*x[j]*y[j]*np.sin(utest[j])*Dutest[j,i] + 2.0*x[j]*np.sin(utest[j]) - 2.0*y[j]*np.cos(utest[j]) +  \
# C:\Users\Thomas\AppData\Local\Temp\ipykernel_41472\4256709949.py:113: RuntimeWarning: overflow encountered in double_scalars
#   (x[j]**2 - y[j]**2)*np.cos(utest[j])*Dutest[j,i] + np.cos(utest[j])*Dutest[j,i])/2  + omega[j] - (K/(M))*(yjdum)
# C:\Users\Thomas\AppData\Local\Temp\ipykernel_41472\4256709949.py:113: RuntimeWarning: invalid value encountered in double_scalars
#   (x[j]**2 - y[j]**2)*np.cos(utest[j])*Dutest[j,i] + np.cos(utest[j])*Dutest[j,i])/2  + omega[j] - (K/(M))*(yjdum)
# C:\Users\Thomas\AppData\Local\Temp\ipykernel_41472\4256709949.py:116: RuntimeWarning: overflow encountered in double_scalars
#   xjdum = y[j]*x[j]
# C:\Users\Thomas\AppData\Local\Temp\ipykernel_41472\4256709949.py:121: RuntimeWarning: overflow encountered in double_scalars
#   J[2*j,i] = -F*(2.0*x[j]*y[j]*np.cos(utest[j])*Dutest[j,i] + 2.0*x[j]*np.sin(utest[j]) - 2.0*y[j]*np.cos(utest[j]) - \
# C:\Users\Thomas\AppData\Local\Temp\ipykernel_41472\4256709949.py:122: RuntimeWarning: overflow encountered in double_scalars
#   (x[j]**2 - 1.0*y[j]**2)*np.sin(utest[j])*Dutest[j,i] + 1.0*np.sin(1.0*utest[j])*Dutest[j,i])/2 - 1.0*omega[j] -(K/(M))*xjdum
# C:\Users\Thomas\AppData\Local\Temp\ipykernel_41472\4256709949.py:122: RuntimeWarning: invalid value encountered in double_scalars
#   (x[j]**2 - 1.0*y[j]**2)*np.sin(utest[j])*Dutest[j,i] + 1.0*np.sin(1.0*utest[j])*Dutest[j,i])/2 - 1.0*omega[j] -(K/(M))*xjdum
# C:\Users\Thomas\AppData\Local\Temp\ipykernel_41472\4256709949.py:124: RuntimeWarning: overflow encountered in double_scalars
#   yjdum = x[j]**2 +3*y[j]**2 -1
# C:\Users\Thomas\AppData\Local\Temp\ipykernel_41472\4256709949.py:129: RuntimeWarning: overflow encountered in double_scalars
#   J[2*j+1,i] = F*(2.0*x[j]*y[j]*np.sin(utest[j])*Dutest[j,i] - 2.0*x[j]*np.cos(utest[j]) - 2.0*y[j]*np.sin(utest[j]) + \
# C:\Users\Thomas\AppData\Local\Temp\ipykernel_41472\4256709949.py:130: RuntimeWarning: overflow encountered in double_scalars
#   1.0*(x[j]**2 - y[j]**2)*np.cos(utest[j])*Dutest[j,i] + 1.0*np.cos(1.0*utest[j])*Dutest[j,i])/2  - 1.0 - (K/(2*M))*yjdum
# C:\Users\Thomas\AppData\Local\Temp\ipykernel_41472\4256709949.py:130: RuntimeWarning: invalid value encountered in double_scalars
#   1.0*(x[j]**2 - y[j]**2)*np.cos(utest[j])*Dutest[j,i] + 1.0*np.cos(1.0*utest[j])*Dutest[j,i])/2  - 1.0 - (K/(2*M))*yjdum
# C:\Users\Thomas\AppData\Local\Temp\ipykernel_41472\4256709949.py:33: RuntimeWarning: overflow encountered in double_scalars
#   Y[j*2] = -F*(2*x[j]*y[j]*np.sin(utest[j]) + (x[j]**2 - y[j]**2)*np.cos(utest[j]) - np.cos(utest[j]))/2 - x[j] - omega[j]*y[j]    - \
# C:\Users\Thomas\AppData\Local\Temp\ipykernel_41472\4256709949.py:33: RuntimeWarning: invalid value encountered in double_scalars
#   Y[j*2] = -F*(2*x[j]*y[j]*np.sin(utest[j]) + (x[j]**2 - y[j]**2)*np.cos(utest[j]) - np.cos(utest[j]))/2 - x[j] - omega[j]*y[j]    - \
# C:\Users\Thomas\AppData\Local\Temp\ipykernel_41472\4256709949.py:38: RuntimeWarning: overflow encountered in double_scalars
#   Y[1+j*2] = F*(-2*x[j]*y[j]*np.cos(utest[j]) + (x[j]**2 - y[j]**2)*np.sin(utest[j]) + np.sin(utest[j]))/2  + omega[j]*x[j]-y[j] - \
# C:\Users\Thomas\AppData\Local\Temp\ipykernel_41472\4256709949.py:38: RuntimeWarning: invalid value encountered in double_scalars
#   Y[1+j*2] = F*(-2*x[j]*y[j]*np.cos(utest[j]) + (x[j]**2 - y[j]**2)*np.sin(utest[j]) + np.sin(utest[j]))/2  + omega[j]*x[j]-y[j] - \
# 0.001672881027142463
# C:\Users\Thomas\AppData\Local\Temp\ipykernel_41472\4256709949.py:110: RuntimeWarning: invalid value encountered in double_scalars
#   yjdum += x[k]*y[j]-y[k]*x[j]
# C:\Users\Thomas\AppData\Local\Temp\ipykernel_41472\4256709949.py:119: RuntimeWarning: invalid value encountered in double_scalars
#   xjdum += y[k]*x[j]- x[k]*y[j]
# 0.001579967696150506
# 0.0014906255724361124
# 0.0014042095991414238
# 0.0013218580344544694
# 0.001244941664386587
# 0.001171126167759545
# 0.0011025838002673802
# 0.0010387610403817665
# 0.0009787716269391053
# 0.000923217308755362
# 0.0008715891496096111
# 0.0008234398846731186
# 0.0007787907195041074
# 0.0007376277657174931
# 0.00069973054119215
# 0.0006636792986931149
# 0.0006304011840781244

# %%
import shelve

KL_dict = dict()
KL_dict['Klist'] = Klist
KL_dict['lya'] = LE_list

with shelve.open(f'shelve/LE.shelve', 'c') as shelf:
    shelf['4d'] = KL_dict

# %%
LE2_list
# Out:
# [array([nan, nan, nan]),
#  array([nan, nan, nan]),
#  array([nan, nan, nan]),
#  array([nan, nan, nan]),
#  array([nan, nan, nan]),
#  array([nan, nan, nan]),
#  array([nan, nan, nan]),
#  array([nan, nan, nan]),
#  array([nan, nan, nan]),
#  array([nan, nan, nan]),
#  array([nan, nan, nan]),
#  array([nan, nan, nan]),
#  array([nan, nan, nan]),
#  array([nan, nan, nan]),
#  array([nan, nan, nan]),
#  array([nan, nan, nan]),
#  array([nan, nan, nan]),
#  array([  0.022,  -0.344, -12.679]),
#  array([  0.026,  -0.749, -12.367]),
#  array([  0.014,  -0.474, -12.744])]

# %%
LE1 = []
for LE in LE_list:
    LE1.append(np.round(LE[0],2))

# %%
LE_list[3]
# Out:
# array([ -0.023,  -0.415, -13.184])

# %%
K_av = []
LE_av = []
for i in range(len(LE1)-3):
    LE_av.append(np.mean([np.round(l,1)for l in LE1[i:i+3]]))
    K_av.append(np.mean(Klist[i:i+3]))

# %%
plt.plot(K_av[:-38],LE_av[:-38])
plt.grid()
plt.savefig(f'shelve/pictures_paper/4d/l1_K.jpg',dpi=300,bbox_inches = 'tight')
#set size

# %%
omega0
# Out:
# array([ 0.43, -0.07, -0.09,  0.03])

# %%
plt.plot(Klist,LE1,'.')

# %%
initlen=5_000
trainlen=20_000
testlen=10_000
M=4
N=3
pvec=[0,1,2,2]

K0=50
h=0.01
F0 = 55
uin = 0.01
omega0 = np.round(np.array([ 0.4254, -0.0726, -0.0892,  0.0301]),2)
p= np.array([uin,K0,F0])






h=0.01
reg=1e-11
z0 = np.ones(M)
while np.any(np.abs(z0)>1): 
    z0 = (np.random.rand(M)*1j + np.random.rand(M))


znew = whipeout(initlen, ut0,utmid,ut1, z0, h,omega0,p,pvec)
Ztrain = kura_run(M,trainlen, ut0[:,initlen:], utmid[:,initlen:],ut1[:,initlen:], znew, h,omega0,p,pvec)
Xtrain = np.angle(Ztrain)
X =  np.concatenate((np.expand_dims(np.ones(Xtrain.shape[1]),axis=0),np.sin(Xtrain),np.sin(Xtrain)**2),axis=0)

Yt = data_scaled[:,::20][:,(initlen+1):(initlen+trainlen+1)].T
Ytest = data_scaled[:,::20][:,(initlen+trainlen+1):(initlen+trainlen+1+testlen)]

Wout = np.linalg.solve( np.dot(X,X.T) + reg*np.eye(2*len(z0)+1) , np.dot(X,Yt) ).T

pred = (Wout @ X)
nmse_train = NMSE(  pred, Yt.T).mean()
print(nmse_train)
z0 = Ztrain[:,-1]

x0 = np.real(z0)
y0 = np.imag(z0)
X_Y = np.zeros(M*2)
for i in range(M):
    X_Y[2*i] = x0[i]
    X_Y[2*i+1] = y0[i]
LE,trJ , Upred =  solve_lya(X_Y, Wout,omega0,p,pvec, M, N, 10_000, h,k=M*2)
LE_shelf = LE[:,5000:]
# Out:
# 4.290295362350232e-05
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 56
#      54 ax.set_xlim(-20, 22)
#      55 ax.set_ylim(-20, 22)
# ---> 56 ax.xaxis.set_ticks([np.arange(-20, 21, 10)])
#      57 ax.yaxis.set_ticks(np.arange(-20, 21, 10))
#      58 ax.zaxis.set_ticks(np.arange(0, 41, 10))
#
# File ~\anaconda3\envs\kura_res\lib\site-packages\matplotlib\axis.py:2074, in Axis.set_ticks(self, ticks, labels, minor, **kwargs)
#    2071 if labels is None and kwargs:
#    2072     raise ValueError('labels argument cannot be None when '
#    2073                      'kwargs are passed')
# -> 2074 result = self._set_tick_locations(ticks, minor=minor)
#    2075 if labels is not None:
#    2076     self.set_ticklabels(labels, minor=minor, **kwargs)
#
# File ~\anaconda3\envs\kura_res\lib\site-packages\matplotlib\axis.py:2015, in Axis._set_tick_locations(self, ticks, minor)
#    2010 def _set_tick_locations(self, ticks, *, minor=False):
#    2011     # see docstring of set_ticks
#    2012
#    2013     # XXX if the user changes units, the information will be lost here
#    2014     ticks = self.convert_units(ticks)
# -> 2015     locator = mticker.FixedLocator(ticks)  # validate ticks early.
#    2016     for name, axis in self.axes._axis_map.items():
#    2017         if self is axis:
#
# File ~\anaconda3\envs\kura_res\lib\site-packages\matplotlib\ticker.py:1718, in FixedLocator.__init__(self, locs, nbins)
#    1716 def __init__(self, locs, nbins=None):
#    1717     self.locs = np.asarray(locs)
# -> 1718     _api.check_shape((None,), locs=self.locs)
#    1719     self.nbins = max(nbins, 2) if nbins is not None else None
#
# File ~\anaconda3\envs\kura_res\lib\site-packages\matplotlib\_api\__init__.py:168, in check_shape(_shape, **kwargs)
#     165 if len(target_shape) == 1:
#     166     text_shape += ","
# --> 168 raise ValueError(
#     169     f"{k!r} must be {len(target_shape)}D "
#     170     f"with shape ({text_shape}). "
#     171     f"Your input has shape {v.shape}."
#     172 )
#
# ValueError: 'locs' must be 1D with shape (M,). Your input has shape (1, 5).

# %%
ax = plt.figure().add_subplot(projection='3d')
ax.plot(*Upred[:,:10_000], lw=0.5,alpha=0.5)

ax.set_zlim(0, 43)
ax.set_xlim(-20, 22)
ax.set_ylim(-20, 22)
ax.xaxis.set_ticks(np.arange(-20, 21, 10))
ax.yaxis.set_ticks(np.arange(-20, 21, 10))
ax.zaxis.set_ticks(np.arange(0, 41, 10))

ax.xaxis.set_ticklabels([])
ax.yaxis.set_ticklabels([])
ax.zaxis.set_ticklabels([])
plt.savefig(f'shelve/pictures_paper/4d/{K0}_{np.round(LE[:3,-500:].mean(axis=1),3)}.jpg',dpi=300,bbox_inches = 'tight')
plt.show()
plt.close()

# %%
    ax = plt.figure().add_subplot(projection='3d')

    ax.plot(*Ytest,color='green',lw=0.5,alpha=0.5)
    ax.set_zlim(0, 43)
    ax.set_xlim(-20, 22)
    ax.set_ylim(-20, 22)
    ax.xaxis.set_ticks(np.arange(-20, 21, 10))
    ax.yaxis.set_ticks(np.arange(-20, 21, 10))
    ax.zaxis.set_ticks(np.arange(0, 41, 10))
    ax.xaxis.set_ticklabels([])
    ax.yaxis.set_ticklabels([])
    ax.zaxis.set_ticklabels([])
    plt.savefig(f'shelve/pictures_paper/4d/data.jpg',dpi=300,bbox_inches = 'tight')
